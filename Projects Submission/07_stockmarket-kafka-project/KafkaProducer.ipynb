# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.3.1-py2.py3-none-any.whl.metadata (9.5 kB)
# Downloading kafka_python-2.3.1-py2.py3-none-any.whl (326 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['54.82.49.91:9092'], #change ip here
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
producer.send('demo_test', value={'test':'hello'})
# Out:
# ---------------------------------------------------------------------------
# KafkaTimeoutError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 producer.send('demo_test', value={'test':'hello'})
#
# File c:\Users\taha_\anaconda3\Lib\site-packages\kafka\producer\kafka.py:844, in KafkaProducer.send(self, topic, value, key, headers, partition, timestamp_ms)
#     842 assigned_partition = None
#     843 while assigned_partition is None and not timer.expired:
# --> 844     self._wait_on_metadata(topic, timer.timeout_ms)
#     846     key_bytes = self._serialize(
#     847         self.config['key_serializer'],
#     848         topic, key)
#     849     value_bytes = self._serialize(
#     850         self.config['value_serializer'],
#     851         topic, value)
#
# File c:\Users\taha_\anaconda3\Lib\site-packages\kafka\producer\kafka.py:968, in KafkaProducer._wait_on_metadata(self, topic, max_wait_ms)
#     966 metadata_event.wait(timer.timeout_ms / 1000)
#     967 if not future.is_done:
# --> 968     raise Errors.KafkaTimeoutError(
#     969         "Failed to update metadata after %.1f secs." % (max_wait_ms / 1000,))
#     970 elif future.failed() and not future.retriable():
#     971     raise future.exception
#
# KafkaTimeoutError: KafkaTimeoutError: Failed to update metadata after 60.0 secs.

# %%
df = pd.read_csv("data/indexProcessed.csv")

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient="records")[0]
    producer.send('demo_test', value=dict_stock)
    sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KafkaTimeoutError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 while True:
#       2     dict_stock = df.sample(1).to_dict(orient="records")[0]
# ----> 3     producer.send('demo_test', value=dict_stock)
#       4     sleep(1)
#
# File c:\Users\taha_\anaconda3\Lib\site-packages\kafka\producer\kafka.py:844, in KafkaProducer.send(self, topic, value, key, headers, partition, timestamp_ms)
#     842 assigned_partition = None
#     843 while assigned_partition is None and not timer.expired:
# --> 844     self._wait_on_metadata(topic, timer.timeout_ms)
#     846     key_bytes = self._serialize(
#     847         self.config['key_serializer'],
#     848         topic, key)
#     849     value_bytes = self._serialize(
#     850         self.config['value_serializer'],
#     851         topic, value)
#
# File c:\Users\taha_\anaconda3\Lib\site-packages\kafka\producer\kafka.py:968, in KafkaProducer._wait_on_metadata(self, topic, max_wait_ms)
#     966 metadata_event.wait(timer.timeout_ms / 1000)
#     967 if not future.is_done:
# --> 968     raise Errors.KafkaTimeoutError(
#     969         "Failed to update metadata after %.1f secs." % (max_wait_ms / 1000,))
#     970 elif future.failed() and not future.retriable():
#     971     raise future.exception
#
# KafkaTimeoutError: KafkaTimeoutError: Failed to update metadata after 60.0 secs.

# %%
producer.flush() #clear data from kafka server
